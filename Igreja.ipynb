# %% [markdown]
# <a href="https://colab.research.google.com/github/joice-oliveira1611/banco-de-dados-com-SQlite/blob/main/Igreja.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<!DOCTYPE html>
<html lang="pt-BR">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Igreja Comunidade Cristã</title>
    <script src="https://cdn.tailwindcss.com"></script>
    <style>
        @import url('https://fonts.googleapis.com/css2?family=Inter:wght@300;400;500;600;700&display=swap');
        body { font-family: 'Inter', sans-serif; }
        .hero-bg {
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
        }
        .scroll-smooth { scroll-behavior: smooth; }
    </style>
</head>
<body class="scroll-smooth">
    <!-- Header/Navigation -->
    <nav class="bg-white shadow-lg fixed w-full top-0 z-50">
        <div class="max-w-7xl mx-auto px-4 sm:px-6 lg:px-8">
            <div class="flex justify-between items-center h-16">
                <div class="flex items-center">
                    <div class="text-2xl font-bold text-purple-700">✝️ Igreja Comunidade</div>
                </div>
                <div class="hidden md:block">
                    <div class="ml-10 flex items-baseline space-x-8">
                        <a href="#inicio" class="text-gray-700 hover:text-purple-700 px-3 py-2 text-sm font-medium transition-colors">Início</a>
                        <a href="#sobre" class="text-gray-700 hover:text-purple-700 px-3 py-2 text-sm font-medium transition-colors">Sobre</a>
                        <a href="#cultos" class="text-gray-700 hover:text-purple-700 px-3 py-2 text-sm font-medium transition-colors">Cultos</a>
                        <a href="#ministerios" class="text-gray-700 hover:text-purple-700 px-3 py-2 text-sm font-medium transition-colors">Ministérios</a>
                        <a href="#contato" class="text-gray-700 hover:text-purple-700 px-3 py-2 text-sm font-medium transition-colors">Contato</a>
                    </div>
                </div>
                <div class="md:hidden">
                    <button id="mobile-menu-btn" class="text-gray-700 hover:text-purple-700">
                        <svg class="h-6 w-6" fill="none" viewBox="0 0 24 24" stroke="currentColor">
                            <path stroke-linecap="round" stroke-linejoin="round" stroke-width="2" d="M4 6h16M4 12h16M4 18h16" />
                        </svg>
                    </button>
                </div>
            </div>
        </div>
        <!-- Mobile menu -->
        <div id="mobile-menu" class="md:hidden hidden bg-white border-t">
            <div class="px-2 pt-2 pb-3 space-y-1">
                <a href="#inicio" class="block px-3 py-2 text-gray-700 hover:text-purple-700">Início</a>
                <a href="#sobre" class="block px-3 py-2 text-gray-700 hover:text-purple-700">Sobre</a>
                <a href="#cultos" class="block px-3 py-2 text-gray-700 hover:text-purple-700">Cultos</a>
                <a href="#ministerios" class="block px-3 py-2 text-gray-700 hover:text-purple-700">Ministérios</a>
                <a href="#contato" class="block px-3 py-2 text-gray-700 hover:text-purple-700">Contato</a>
            </div>
        </div>
    </nav>

    <!-- Hero Section -->
    <section id="inicio" class="hero-bg text-white pt-16">
        <div class="max-w-7xl mx-auto px-4 sm:px-6 lg:px-8 py-24">
            <div class="text-center">
                <h1 class="text-5xl md:text-6xl font-bold mb-6">Bem-vindos à Nossa Igreja</h1>
                <p class="text-xl md:text-2xl mb-8 max-w-3xl mx-auto">Uma comunidade de fé, amor e esperança. Venha fazer parte da nossa família cristã.</p>
                <div class="space-x-4">
                    <button onclick="scrollToSection('cultos')" class="bg-white text-purple-700 px-8 py-3 rounded-full font-semibold hover:bg-gray-100 transition-colors">
                        Horários dos Cultos
                    </button>
                    <button onclick="scrollToSection('contato')" class="border-2 border-white text-white px-8 py-3 rounded-full font-semibold hover:bg-white hover:text-purple-700 transition-colors">
                        Visite-nos
                    </button>
                </div>
            </div>
        </div>
    </section>

    <!-- About Section -->
    <section id="sobre" class="py-20 bg-gray-50">
        <div class="max-w-7xl mx-auto px-4 sm:px-6 lg:px-8">
            <div class="text-center mb-16">
                <h2 class="text-4xl font-bold text-gray-900 mb-4">Sobre Nossa Igreja</h2>
                <p class="text-xl text-gray-600 max-w-3xl mx-auto">Somos uma comunidade cristã dedicada a compartilhar o amor de Cristo e servir nossa comunidade com alegria e propósito.</p>
            </div>
            <div class="grid md:grid-cols-3 gap-8">
                <div class="text-center p-6 bg-white rounded-lg shadow-md">
                    <div class="text-4xl mb-4">🙏</div>
                    <h3 class="text-xl font-semibold mb-3">Adoração</h3>
                    <p class="text-gray-600">Cultos inspiradores com música contemporânea e mensagens transformadoras da Palavra de Deus.</p>
                </div>
                <div class="text-center p-6 bg-white rounded-lg shadow-md">
                    <div class="text-4xl mb-4">❤️</div>
                    <h3 class="text-xl font-semibold mb-3">Comunhão</h3>
                    <p class="text-gray-600">Uma família acolhedora onde todos são bem-vindos e podem crescer juntos na fé.</p>
                </div>
                <div class="text-center p-6 bg-white rounded-lg shadow-md">
                    <div class="text-4xl mb-4">🤝</div>
                    <h3 class="text-xl font-semibold mb-3">Serviço</h3>
                    <p class="text-gray-600">Projetos sociais e missionários para impactar positivamente nossa comunidade.</p>
                </div>
            </div>
        </div>
    </section>

    <!-- Service Times -->
    <section id="cultos" class="py-20 bg-white">
        <div class="max-w-7xl mx-auto px-4 sm:px-6 lg:px-8">
            <div class="text-center mb-16">
                <h2 class="text-4xl font-bold text-gray-900 mb-4">Horários dos Cultos</h2>
                <p class="text-xl text-gray-600">Venha adorar conosco! Todos são bem-vindos.</p>
            </div>
            <div class="grid md:grid-cols-2 lg:grid-cols-3 gap-8">
                <div class="bg-purple-50 p-8 rounded-lg text-center">
                    <h3 class="text-2xl font-bold text-purple-700 mb-4">Domingo</h3>
                    <div class="space-y-3">
                        <div class="bg-white p-4 rounded-lg">
                            <p class="font-semibold">Escola Dominical</p>
                            <p class="text-gray-600">9:00 - 10:00</p>
                        </div>
                        <div class="bg-white p-4 rounded-lg">
                            <p class="font-semibold">Culto Principal</p>
                            <p class="text-gray-600">10:30 - 12:00</p>
                        </div>
                        <div class="bg-white p-4 rounded-lg">
                            <p class="font-semibold">Culto da Noite</p>
                            <p class="text-gray-600">19:00 - 20:30</p>
                        </div>
                    </div>
                </div>
                <div class="bg-blue-50 p-8 rounded-lg text-center">
                    <h3 class="text-2xl font-bold text-blue-700 mb-4">Quarta-feira</h3>
                    <div class="space-y-3">
                        <div class="bg-white p-4 rounded-lg">
                            <p class="font-semibold">Estudo Bíblico</p>
                            <p class="text-gray-600">19:30 - 21:00</p>
                        </div>
                    </div>
                </div>
                <div class="bg-green-50 p-8 rounded-lg text-center">
                    <h3 class="text-2xl font-bold text-green-700 mb-4">Sexta-feira</h3>
                    <div class="space-y-3">
                        <div class="bg-white p-4 rounded-lg">
                            <p class="font-semibold">Culto de Jovens</p>
                            <p class="text-gray-600">19:30 - 21:30</p>
                        </div>
                    </div>
                </div>
            </div>
        </div>
    </section>

    <!-- Ministries -->
    <section id="ministerios" class="py-20 bg-gray-50">
        <div class="max-w-7xl mx-auto px-4 sm:px-6 lg:px-8">
            <div class="text-center mb-16">
                <h2 class="text-4xl font-bold text-gray-900 mb-4">Nossos Ministérios</h2>
                <p class="text-xl text-gray-600">Encontre seu lugar para servir e crescer na fé.</p>
            </div>
            <div class="grid md:grid-cols-2 lg:grid-cols-4 gap-8">
                <div class="bg-white p-6 rounded-lg shadow-md text-center hover:shadow-lg transition-shadow">
                    <div class="text-3xl mb-4">🎵</div>
                    <h3 class="text-lg font-semibold mb-2">Ministério de Louvor</h3>
                    <p class="text-gray-600 text-sm">Música e adoração nos cultos</p>
                </div>
                <div class="bg-white p-6 rounded-lg shadow-md text-center hover:shadow-lg transition-shadow">
                    <div class="text-3xl mb-4">👶</div>
                    <h3 class="text-lg font-semibold mb-2">Ministério Infantil</h3>
                    <p class="text-gray-600 text-sm">Cuidado e ensino para crianças</p>
                </div>
                <div class="bg-white p-6 rounded-lg shadow-md text-center hover:shadow-lg transition-shadow">
                    <div class="text-3xl mb-4">🌟</div>
                    <h3 class="text-lg font-semibold mb-2">Ministério de Jovens</h3>
                    <p class="text-gray-600 text-sm">Atividades para adolescentes</p>
                </div>
                <div class="bg-white p-6 rounded-lg shadow-md text-center hover:shadow-lg transition-shadow">
                    <div class="text-3xl mb-4">🤲</div>
                    <h3 class="text-lg font-semibold mb-2">Ação Social</h3>
                    <p class="text-gray-600 text-sm">Projetos comunitários</p>
                </div>
            </div>
        </div>
    </section>

    <!-- Contact -->
    <section id="contato" class="py-20 bg-white">
        <div class="max-w-7xl mx-auto px-4 sm:px-6 lg:px-8">
            <div class="text-center mb-16">
                <h2 class="text-4xl font-bold text-gray-900 mb-4">Entre em Contato</h2>
                <p class="text-xl text-gray-600">Estamos aqui para você. Venha nos visitar!</p>
            </div>
            <div class="grid md:grid-cols-2 gap-12">
                <div>
                    <h3 class="text-2xl font-bold mb-6">Informações de Contato</h3>
                    <div class="space-y-4">
                        <div class="flex items-center">
                            <div class="text-purple-700 mr-4">📍</div>
                            <div>
                                <p class="font-semibold">Endereço</p>
                                <p class="text-gray-600">Rua da Fé, 123 - Centro<br>São Paulo, SP - 01234-567</p>
                            </div>
                        </div>
                        <div class="flex items-center">
                            <div class="text-purple-700 mr-4">📞</div>
                            <div>
                                <p class="font-semibold">Telefone</p>
                                <p class="text-gray-600">(11) 1234-5678</p>
                            </div>
                        </div>
                        <div class="flex items-center">
                            <div class="text-purple-700 mr-4">✉️</div>
                            <div>
                                <p class="font-semibold">Email</p>
                                <p class="text-gray-600">contato@igrejacomunidade.com.br</p>
                            </div>
                        </div>
                        <div class="flex items-center">
                            <div class="text-purple-700 mr-4">⏰</div>
                            <div>
                                <p class="font-semibold">Horário de Atendimento</p>
                                <p class="text-gray-600">Segunda a Sexta: 9h às 17h</p>
                            </div>
                        </div>
                    </div>
                </div>
                <div class="bg-gray-50 p-8 rounded-lg">
                    <h3 class="text-2xl font-bold mb-6">Envie uma Mensagem</h3>
                    <div class="bg-yellow-100 border border-yellow-400 text-yellow-800 px-4 py-3 rounded mb-4">
                        <p class="text-sm"><strong>Demo:</strong> Este formulário é apenas para demonstração. Para um site real, seria necessário configurar um sistema de backend para processar as mensagens.</p>
                    </div>
                    <form class="space-y-4">
                        <div>
                            <label class="block text-sm font-medium text-gray-700 mb-1">Nome</label>
                            <input type="text" class="w-full px-3 py-2 border border-gray-300 rounded-md focus:outline-none focus:ring-2 focus:ring-purple-500" placeholder="Seu nome completo">
                        </div>
                        <div>
                            <label class="block text-sm font-medium text-gray-700 mb-1">Email</label>
                            <input type="email" class="w-full px-3 py-2 border border-gray-300 rounded-md focus:outline-none focus:ring-2 focus:ring-purple-500" placeholder="seu@email.com">
                        </div>
                        <div>
                            <label class="block text-sm font-medium text-gray-700 mb-1">Mensagem</label>
                            <textarea rows="4" class="w-full px-3 py-2 border border-gray-300 rounded-md focus:outline-none focus:ring-2 focus:ring-purple-500" placeholder="Sua mensagem..."></textarea>
                        </div>
                        <button type="button" onclick="showDemoMessage()" class="w-full bg-purple-700 text-white py-2 px-4 rounded-md hover:bg-purple-800 transition-colors">
                            Enviar Mensagem
                        </button>
                    </form>
                </div>
            </div>
        </div>
    </section>

    <!-- Footer -->
    <footer class="bg-gray-900 text-white py-12">
        <div class="max-w-7xl mx-auto px-4 sm:px-6 lg:px-8">
            <div class="grid md:grid-cols-3 gap-8">
                <div>
                    <h3 class="text-2xl font-bold mb-4">✝️ Igreja Comunidade</h3>
                    <p class="text-gray-400">Uma comunidade de fé, amor e esperança, dedicada a compartilhar o amor de Cristo.</p>
                </div>
                <div>
                    <h4 class="text-lg font-semibold mb-4">Links Rápidos</h4>
                    <ul class="space-y-2">
                        <li><a href="#inicio" class="text-gray-400 hover:text-white transition-colors">Início</a></li>
                        <li><a href="#sobre" class="text-gray-400 hover:text-white transition-colors">Sobre</a></li>
                        <li><a href="#cultos" class="text-gray-400 hover:text-white transition-colors">Cultos</a></li>
                        <li><a href="#ministerios" class="text-gray-400 hover:text-white transition-colors">Ministérios</a></li>
                    </ul>
                </div>
                <div>
                    <h4 class="text-lg font-semibold mb-4">Redes Sociais</h4>
                    <div class="flex space-x-4">
                        <button class="text-gray-400 hover:text-white transition-colors text-2xl">📘</button>
                        <button class="text-gray-400 hover:text-white transition-colors text-2xl">📷</button>
                        <button class="text-gray-400 hover:text-white transition-colors text-2xl">🐦</button>
                        <button class="text-gray-400 hover:text-white transition-colors text-2xl">📺</button>
                    </div>
                </div>
            </div>
            <div class="border-t border-gray-800 mt-8 pt-8 text-center">
                <p class="text-gray-400">&copy; 2024 Igreja Comunidade Cristã. Todos os direitos reservados.</p>
            </div>
        </div>
    </footer>

    <script>
        // Mobile menu toggle
        document.getElementById('mobile-menu-btn').addEventListener('click', function() {
            const mobileMenu = document.getElementById('mobile-menu');
            mobileMenu.classList.toggle('hidden');
        });

        // Smooth scrolling function
        function scrollToSection(sectionId) {
            document.getElementById(sectionId).scrollIntoView({
                behavior: 'smooth'
            });
        }

        // Demo message for contact form
        function showDemoMessage() {
            alert('Obrigado pela sua mensagem! Em um site real, esta mensagem seria enviada para a igreja. Este é apenas um exemplo de demonstração.');
        }

        // Close mobile menu when clicking on links
        document.querySelectorAll('#mobile-menu a').forEach(link => {
            link.addEventListener('click', function() {
                document.getElementById('mobile-menu').classList.add('hidden');
            });
        });

        // Smooth scroll for navigation links
        document.querySelectorAll('a[href^="#"]').forEach(anchor => {
            anchor.addEventListener('click', function (e) {
                e.preventDefault();
                const target = document.querySelector(this.getAttribute('href'));
                if (target) {
                    target.scrollIntoView({
                        behavior: 'smooth',
                        block: 'start'
                    });
                }
            });
        });
    </script>
<script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'9754146fb52c0120',t:'MTc1NjIxOTE3OS4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
</html>
